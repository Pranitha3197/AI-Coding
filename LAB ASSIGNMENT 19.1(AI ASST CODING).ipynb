# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranitha3197/AI-Coding/blob/main/LAB%20ASSIGNMENT%2019.1(AI%20ASST%20CODING).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TASK 1**

# %%
# Python Class
class Employee:
    def __init__(self, name, salary):
        self.name = name
        self.salary = salary

    def display_info(self):
        print(f"Name: {self.name}")
        print(f"Salary: {self.salary}")

    def increase_salary(self, amount):
        self.salary += amount


# Run Python version
emp = Employee("John", 50000)
emp.display_info()

emp.increase_salary(5000)
print("\nAfter Salary Increase:")
emp.display_info()
# Out:
# Name: John
# Salary: 50000
#
# After Salary Increase:
# Name: John
# Salary: 55000

# %%
# %%writefile Employee.java
# class Employee {
#     String name;
#     double salary;
#
#     // Constructor
#     Employee(String name, double salary) {
#         this.name = name;
#         this.salary = salary;
#     }
#
#     void displayInfo() {
#         System.out.println("Name: " + name);
#         System.out.println("Salary: " + salary);
#     }
#
#     void increaseSalary(double amount) {
#         salary += amount;
#     }
#
#     public static void main(String[] args) {
#         Employee emp = new Employee("John", 50000);
#
#         emp.displayInfo();
#
#         emp.increaseSalary(5000);
#         System.out.println("\nAfter Salary Increase:");
#         emp.displayInfo();
#     }
# }
# Out:
# Writing Employee.java

# %%
# !javac Employee.java

# %%
# !java Employee
# Out:
# Name: John
# Salary: 50000.0
#
# After Salary Increase:
# Name: John
# Salary: 55000.0

# %% [markdown]
# **TASK 2**

# %%
# Python recursive factorial
def factorial(n):
    if n < 0:
        raise ValueError("Factorial not defined for negative numbers")
    if n in (0, 1):
        return 1
    return n * factorial(n - 1)

# Test
num = 5
print(f"Factorial of {num} is {factorial(num)}")

# More tests
for val in [0, 1, 3, 5, 7]:
    print(f"{val}! = {factorial(val)}")
# Out:
# Factorial of 5 is 120
# 0! = 1
# 1! = 1
# 3! = 6
# 5! = 120
# 7! = 5040

# %%
# %%writefile factorial.cpp
# #include <iostream>
# using namespace std;
#
# int factorial(int n) {
#     if (n == 0 || n == 1)
#         return 1;
#     return n * factorial(n - 1);
# }
#
# int main() {
#     int num = 5;
#     cout << "Factorial of " << num << " is " << factorial(num) << endl;
#
#     // Extra test cases
#     int test[] = {0, 1, 3, 5, 7};
#     for (int i = 0; i < 5; i++) {
#         cout << test[i] << "! = " << factorial(test[i]) << endl;
#     }
#
#     return 0;
# }
# Out:
# Writing factorial.cpp

# %%
# !g++ factorial.cpp -o factorial

# %%
# !./factorial
# Out:
# Factorial of 5 is 120
# 0! = 1
# 1! = 1
# 3! = 6
# 5! = 120
# 7! = 5040

# %% [markdown]
# **TASK 3**

# %%
import pandas as pd

# Create sample employee dataset
data = {
    'name': ['John', 'Alice', 'Bob', 'Emma', 'David'],
    'salary': [40000, 60000, 55000, 45000, 70000],
    'department': ['HR', 'IT', 'Finance', 'IT', 'HR']
}

df = pd.DataFrame(data)

print("Original Data:")
display(df)
# Out:
# Original Data:
#     name  salary department
# 0   John   40000         HR
# 1  Alice   60000         IT
# 2    Bob   55000    Finance
# 3   Emma   45000         IT
# 4  David   70000         HR

# %%
# SQL Query:
# SELECT name, salary
# FROM employees
# WHERE salary > 50000;

# %%
# Pandas equivalent
result = df.loc[df['salary'] > 50000, ['name', 'salary']]

print("Filtered Data:")
display(result)
# Out:
# Filtered Data:
#     name  salary
# 1  Alice   60000
# 2    Bob   55000
# 4  David   70000

# %%
# Check if result is correct
expected_names = ['Alice', 'Bob', 'David']

if list(result['name']) == expected_names:
    print("✅ Correct Output")
else:
    print("❌ Something is wrong")
# Out:
# ✅ Correct Output

# %% [markdown]
# **TASK 4**

# %%
# Python version (BeautifulSoup)

from bs4 import BeautifulSoup

# Sample HTML (simulate webpage)
html = """
<html>
  <body>
    <h1>Products</h1>
    <p class="price">100</p>
    <p class="price">200</p>
    <p class="price">300</p>
  </body>
</html>
"""

# Parse HTML
soup = BeautifulSoup(html, "html.parser")

# Extract prices
prices = [int(p.text) for p in soup.find_all("p", class_="price")]

print("Python Output:", prices)
# Out:
# Python Output: [100, 200, 300]

# %%
# Run JavaScript using Node.js

# !apt-get install nodejs -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   javascript-common libc-ares2 libjs-highlight.js libnode72 nodejs-doc
# Suggested packages:
#   apache2 | lighttpd | httpd npm
# The following NEW packages will be installed:
#   javascript-common libc-ares2 libjs-highlight.js libnode72 nodejs nodejs-doc
# 0 upgraded, 6 newly installed, 0 to remove and 6 not upgraded.
# Need to get 13.7 MB of archives.
# After this operation, 54.0 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 javascript-common all 11+nmu1 [5,936 B]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libjs-highlight.js all 9.18.5+dfsg1-1 [367 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libc-ares2 amd64 1.18.1-1ubuntu0.22.04.3 [45.1 kB]
# ...

# %%
# %%writefile script.js
#
# // JavaScript version
#
# const html = `
# <html>
#   <body>
#     <h1>Products</h1>
#     <p class="price">100</p>
#     <p class="price">200</p>
#     <p class="price">300</p>
#   </body>
# </html>
# `;
#
# // Extract prices using regex (simple simulation)
# const prices = [...html.matchAll(/<p class="price">(.*?)<\/p>/g)]
#                 .map(match => parseInt(match[1]));
#
# console.log("JavaScript Output:", prices);
# Out:
# Writing script.js

# %%
# !node script.js
# Out:
# JavaScript Output: [ 100, 200, 300 ]
