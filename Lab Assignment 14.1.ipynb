# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranitha3197/AI-Coding/blob/main/Lab%20Assignment%2014.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Task 1
#
# Prompt:
# Generate a responsive personal portfolio website using HTML, CSS, and JavaScript.
# Include sections: About Me, Projects, Contact.
# Use Flexbox or Grid for layout.
# Add smooth scrolling navigation.
# Suggest a modern color palette and clean typography.
#
# Code Explanation:
# The code creates a portfolio webpage with About, Projects, and Contact sections connected through a fixed navigation bar.
# CSS is used for layout styling and smooth scrolling, making navigation between sections user-friendly.

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Portfolio</title>
# <style>
# body {font-family: Arial; margin:0;}
# nav {background:#333; padding:10px; position:fixed; width:100%;}
# nav a {color:white; margin:10px; text-decoration:none;}
# section {padding:80px 20px; height:100vh;}
# #about {background:#f4f4f4;}
# #projects {background:#ddd;}
# #contact {background:#bbb;}
#
# html {scroll-behavior:smooth;}
# </style>
# </head>
# <body>
#
# <nav>
# <a href="#about">About</a>
# <a href="#projects">Projects</a>
# <a href="#contact">Contact</a>
# </nav>
#
# <section id="about">
# <h2>About Me</h2>
# <p>I am a web developer.</p>
# </section>
#
# <section id="projects">
# <h2>Projects</h2>
# <p>My projects here.</p>
# </section>
#
# <section id="contact">
# <h2>Contact</h2>
# <p>Email: example@gmail.com</p>
# </section>
#
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Portfolio</title>
# <style>
# body {font-family: Arial; margin:0;}
# nav {background:#333; padding:10px; position:fixed; width:100%;}
# nav a {color:white; margin:10px; text-decoration:none;}
# section {padding:80px 20px; height:100vh;}
# #about {background:#f4f4f4;}
# #projects {background:#ddd;}
# #contact {background:#bbb;}
#
# html {scroll-behavior:smooth;}
# </style>
# </head>
# <body>
#
# <nav>
# <a href="#about">About</a>
# <a href="#projects">Projects</a>
# <a href="#contact">Contact</a>
# </nav>
#
# <section id="about">
# <h2>About Me</h2>
# <p>I am a web developer.</p>
# </section>
#
# <section id="projects">
# <h2>Projects</h2>
# <p>My projects here.</p>
# </section>
#
# <section id="contact">
# <h2>Contact</h2>
# <p>Email: example@gmail.com</p>
# </section>
#
# </body>
# </html>

# %% [markdown]
# Task 2
#
# Prompt:
# Create a responsive product page using HTML, CSS, and JavaScript.
# Use BEM naming convention for CSS classes.
# Display product image, title, price, and Add to Cart button.
# Add hover effects and show alert on button click.
#
# Code Explanation :
# The code displays a product with image, title, price, and Add to Cart button using structured BEM class names.
# CSS adds responsive styling and hover effects, while JavaScript shows an alert when the button is clicked.

# %%
# %%html
# <style>
# .product {max-width:300px; margin:auto; text-align:center;}
# .product__img {width:100%;}
# .product__title {font-size:20px;}
# .product__price {color:green;}
# .product__btn {
#   padding:10px;
#   background:black;
#   color:white;
#   cursor:pointer;
# }
# .product__btn:hover {background:orange;}
# </style>
#
# <div class="product">
# <img src="https://via.placeholder.com/300" class="product__img">
# <h2 class="product__title">Smart Watch</h2>
# <p class="product__price">$99</p>
# <button class="product__btn" onclick="alert('Added to cart!')">
# Add to Cart
# </button>
# </div>
# Out:
# <style>
# .product {max-width:300px; margin:auto; text-align:center;}
# .product__img {width:100%;}
# .product__title {font-size:20px;}
# .product__price {color:green;}
# .product__btn {
#   padding:10px;
#   background:black;
#   color:white;
#   cursor:pointer;
# }
# .product__btn:hover {background:orange;}
# </style>
#
# <div class="product">
# <img src="https://via.placeholder.com/300" class="product__img">
# <h2 class="product__title">Smart Watch</h2>
# <p class="product__price">$99</p>
# <button class="product__btn" onclick="alert('Added to cart!')">
# Add to Cart
# </button>
# </div>

# %%
Task 3

Prompt:
Build an accessible event registration form using HTML, CSS, and JavaScript.
Include fields: name, email, phone, session selection.
Add JavaScript validation.
Use proper labels and ARIA attributes for accessibility.
Style the form professionally.

Code Explanation:
The code creates a registration form to collect user details and session selection with labeled input fields.
JavaScript validates the phone number before submission and ensures proper user input handling.

# %%
# %%html
# <form onsubmit="return validateForm()">
# <label>Name:</label><br>
# <input type="text" id="name" required><br><br>
#
# <label>Email:</label><br>
# <input type="email" id="email" required><br><br>
#
# <label>Phone:</label><br>
# <input type="tel" id="phone" required><br><br>
#
# <label>Session:</label><br>
# <select id="session">
# <option>AI</option>
# <option>Web Dev</option>
# </select><br><br>
#
# <button type="submit">Register</button>
# </form>
#
# <script>
# function validateForm(){
# let phone=document.getElementById("phone").value;
# if(phone.length<10){
# alert("Invalid phone number");
# return false;
# }
# alert("Registration successful!");
# return true;
# }
# </script>
# Out:
# <form onsubmit="return validateForm()">
# <label>Name:</label><br>
# <input type="text" id="name" required><br><br>
#
# <label>Email:</label><br>
# <input type="email" id="email" required><br><br>
#
# <label>Phone:</label><br>
# <input type="tel" id="phone" required><br><br>
#
# <label>Session:</label><br>
# <select id="session">
# <option>AI</option>
# <option>Web Dev</option>
# </select><br><br>
#
# <button type="submit">Register</button>
# </form>
#
# <script>
# function validateForm(){
# let phone=document.getElementById("phone").value;
# if(phone.length<10){
# alert("Invalid phone number");
# return false;
# }
# alert("Registration successful!");
# return true;
# }
# </script>

# %% [markdown]
# Task 4
#
# Prompt:
# Create a one-page resume website using HTML and CSS Grid.
# Include sections: Profile Summary, Skills, Education, Experience.
# Use professional typography.
# Add smooth scrolling navigation.
#
# Code Explantion:
# The code builds a one-page resume with sections like Profile, Skills, Education, and Experience arranged using CSS Grid.
# Smooth scrolling navigation and professional typography improve the structure and readability of the resume.

# %%
# %%html
# <style>
# body {font-family: Georgia;}
# .container {
# display:grid;
# grid-template-columns:1fr 2fr;
# gap:20px;
# }
# section {padding:20px;}
# nav a {margin:10px;}
# html {scroll-behavior:smooth;}
# </style>
#
# <nav>
# <a href="#profile">Profile</a>
# <a href="#skills">Skills</a>
# <a href="#edu">Education</a>
# </nav>
#
# <div class="container">
# <section id="profile"><h2>Profile</h2></section>
# <section id="skills"><h2>Skills</h2></section>
# <section id="edu"><h2>Education</h2></section>
# <section><h2>Experience</h2></section>
# </div>
# Out:
# <style>
# body {font-family: Georgia;}
# .container {
# display:grid;
# grid-template-columns:1fr 2fr;
# gap:20px;
# }
# section {padding:20px;}
# nav a {margin:10px;}
# html {scroll-behavior:smooth;}
# </style>
#
# <nav>
# <a href="#profile">Profile</a>
# <a href="#skills">Skills</a>
# <a href="#edu">Education</a>
# </nav>
#
# <div class="container">
# <section id="profile"><h2>Profile</h2></section>
# <section id="skills"><h2>Skills</h2></section>
# <section id="edu"><h2>Education</h2></section>
# <section><h2>Experience</h2></section>
# </div>

# %% [markdown]
# Task 5
#
# Prompt:
# Design a restaurant menu page using HTML and CSS.
# Use a card-based layout for menu items.
# Display name, description, and price.
# Use a warm food-friendly color palette.
# Add hover effects and responsive layout.
#
# Code Explnation:
# The code displays menu items in a responsive card layout with food name, description, and price details.
# CSS hover effects and warm colors improve the visual appeal and user interaction of the menu page.

# %%
# %%html
# <style>
# body {background:#fff8e1; font-family:sans-serif;}
# .menu {display:flex; flex-wrap:wrap; gap:20px;}
# .card {
# border:1px solid #ddd;
# padding:15px;
# width:200px;
# transition:0.3s;
# }
# .card:hover {
# transform:scale(1.05);
# background:#ffe0b2;
# }
# </style>
#
# <div class="menu">
# <div class="card">
# <h3>Pizza</h3>
# <p>Cheesy delight</p>
# <p>$10</p>
# </div>
#
# <div class="card">
# <h3>Burger</h3>
# <p>Juicy beef burger</p>
# <p>$8</p>
# </div>
# </div>
# Out:
# <style>
# body {background:#fff8e1; font-family:sans-serif;}
# .menu {display:flex; flex-wrap:wrap; gap:20px;}
# .card {
# border:1px solid #ddd;
# padding:15px;
# width:200px;
# transition:0.3s;
# }
# .card:hover {
# transform:scale(1.05);
# background:#ffe0b2;
# }
# </style>
#
# <div class="menu">
# <div class="card">
# <h3>Pizza</h3>
# <p>Cheesy delight</p>
# <p>$10</p>
# </div>
#
# <div class="card">
# <h3>Burger</h3>
# <p>Juicy beef burger</p>
# <p>$8</p>
# </div>
# </div>
